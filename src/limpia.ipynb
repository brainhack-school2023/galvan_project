# %%
import pandas as pd
from utils import labelpre as lp
from utils import clean as cl
from utils import processdata as pr

import seaborn as sns

# %%
dt = pr.dataread()
df = pr.datast(dt)
#data.reindex(columns=['Et'])

# %%
df.head()
# Out:
# Ncodigo        cod  afsl_ad afsl_area of end region 1(mm^2)
# 0        sub-10171  1.23721                         1471.85  \
# 1        sub-10189  1.15361                         2234.71
# 2        sub-10206   1.2339                         478.866
# 3        sub-10217  1.18839                         2978.96
# 4        sub-10225  1.23856                         1581.53
#
# Ncodigo afsl_area of end region 2(mm^2) afsl_branch volume(mm^3) afsl_curl
# 0                               1248.58                  11931.5   4.48975  \
# 1                               1009.63                  8798.79   3.73118
# 2                               827.487                  1825.37   3.77463
# 3                               1547.25                  1441.49   3.34588
# 4                               683.534                  7555.11    3.7732
#
# Ncodigo afsl_diameter(mm) afsl_dti_fa afsl_elongation afsl_irregularity  ...
# 0                 16.4691    0.456258         7.18531           7.43516  ...  \
# 1                 15.0666    0.493506         6.87302           6.81786  ...
# 2                  11.911    0.471517         6.58314           5.29834  ...
# 3                 17.8728    0.463511         5.91539           7.33476  ...
# 4                  15.766    0.463871         6.37764           6.94917  ...
#
# Ncodigo ufsr_radius of end region 1(mm) ufsr_radius of end region 2(mm)
# 0                                8.8243                          9.6232  \
# 1                               9.02383                         10.1279
# 2                               8.95602                         8.21973
# 3                                8.6876                         8.48388
# 4                               11.8378                         12.6037
#
# Ncodigo   ufsr_rd  ufsr_rdi ufsr_span(mm)
# 0        0.772912  0.330688       8.97232  \
# 1        0.719298  0.151857       15.1074
# 2        0.826684  0.176348       10.6707
# 3        0.736316  0.335666       9.68421
# 4        0.826085  0.444665       10.1945
#
# Ncodigo ufsr_total area of end regions(mm^2)
# 0                                    2693.99  \
# 1                                    2108.38
# 2                                    933.249
# 3                                    2180.85
# 4                                    691.368
#
# Ncodigo ufsr_total radius of end regions(mm) ufsr_total surface area(mm^2)
# 0                                    18.4475                       21228.7  \
# 1                                    19.1517                       19638.4
# 2                                    17.1757                       12013.7
# 3                                    17.1715                       16714.3
# 4                                    24.4416                         13561
#
# Ncodigo ufsr_trunk volume(mm^3) ufsr_volume(mm^3)
# 0                       9877.95           14154.4
# 1                       7918.42           11760.1
# 2                       2729.24           6178.25
# 3                       10092.4           10799.4
# 4                       1653.02           4666.25
#
# [5 rows x 291 columns]

# %%
columnas = lp.custom()
df.rename(columns=columnas, inplace=True)

# %%
df.shape
# Out:
# (67, 291)

# %%
# Era para probar las funciones, ahora ya estan funcionando
data = pd.read_csv('df.csv')
columnas = lp.custom()
data.rename(columns=columnas, inplace=True)
data = cl.missing_values(data)

# %%
import os
import csv

# Obtener la ruta de la carpeta principal 
folder_path = 'ruta_de_la_carpeta_principal'

# Crear un archivo csv
with open('datos.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Archivo', 'Contenido'])

    # Recorrer las subcarpetas y archivos txt y unirlos en un archivo csv
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.endswith('.txt'):
                filename = os.path.join(root, file)

                # Leer el archivo txt
                with open(filename, 'r') as txt_file:
                    content = txt_file.read()

                # Escribir el contenido en el archivo csv
                writer.writerow([filename, content])

print('¡Listo! Los datos se han guardado en datos.csv')
