# %%
import pandas as pd
from utils import labelpre as lp
from utils import clean as cl
from utils import processdata as pr

import seaborn as sns

# %%
data = pd.read_csv('df.csv')

# %%
columnas = lp.custom()

# %%
data.rename(columns=columnas, inplace=True)

# %%
data = cl.missing_values(data)

# %%
data = pr.dataread()

# %%
data.head()
# Out:
#                        data                                           label
# 0    number of tracts\t8424  sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt\t0  \
# 1  mean length(mm)\t118.336  sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt\t1
# 2         span(mm)\t26.3569  sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt\t2
# 3             curl\t4.48975  sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt\t3
# 4       elongation\t7.18531  sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt\t4
#
#              Codigo   values                                           Et id
# 0  number of tracts     8424  sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt  0
# 1   mean length(mm)  118.336  sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt  1
# 2          span(mm)  26.3569  sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt  2
# 3              curl  4.48975  sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt  3
# 4        elongation  7.18531  sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt  4

# %%
data.reindex(columns=['Et'])
# Out:
#                                                  Et
# 0       sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt
# label   sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt
# 2       sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt
# 3       sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt
# 4       sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt
# ...                                             ...
# 19303  sub-50049_dwi.Uncinate_Fasciculus_R.stat.txt
# 19304  sub-50049_dwi.Uncinate_Fasciculus_R.stat.txt
# 19305  sub-50049_dwi.Uncinate_Fasciculus_R.stat.txt
# 19306  sub-50049_dwi.Uncinate_Fasciculus_R.stat.txt
# 19307  sub-50049_dwi.Uncinate_Fasciculus_R.stat.txt
#
# [18647 rows x 1 columns]

# %%
data.drop(columns = ['data', 'label'], inplace=True)

# %%
data.head()
# Out:
#                        data                                           label
# 0    number of tracts\t8424  sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt\t0  \
# 1  mean length(mm)\t118.336  sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt\t1
# 2         span(mm)\t26.3569  sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt\t2
# 3             curl\t4.48975  sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt\t3
# 4       elongation\t7.18531  sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt\t4
#
#              Codigo   values                                           Et id
# 0  number of tracts     8424  sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt  0
# 1   mean length(mm)  118.336  sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt  1
# 2          span(mm)  26.3569  sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt  2
# 3              curl  4.48975  sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt  3
# 4        elongation  7.18531  sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt  4

# %%
etiq = ['Arcuate_Fasciculus_L',
        'Arcuate_Fasciculus_R',
        'Cingulum_Frontal_Parietal_L',
        'Cingulum_Frontal_Parietal_R',
        'Frontal_Aslant_Tract_L',
        'Frontal_Aslant_Tract_R',
        'Superior_Longitudinal_Fasciculus1_L',
        'Superior_Longitudinal_Fasciculus1_R',
        'Uncinate_Fasciculus_L',
        'Uncinate_Fasciculus_R']

nuevo = ['afsl_',
         'afsr_',
         'cfpl_',
         'cfpr_',         
         'fatl_',
         'fatr_',
         'slfl_',
         'slfr_',
         'ufsl_',
         'ufsr_']

for i in range(0,len(etiq)):
       # print(i)
        print(nuevo[i])
        data['Ncodigo'] = nuevo[i]+data['values'].str.contains(i)
        
        #if data['label'].str.contains(i):
                #data['Ncodigo'] = nuevo[i]+data['values'].str.contains(i).astype(int)
        #        print(i)
# Out:
# afsl_
# afsr_
# cfpl_
# cfpr_
# fatl_
# fatr_
# slfl_
# slfr_
# ufsl_
# ufsr_

# %%
data
# Out:
#                            data
# 0        number of tracts\t8424  \
# 1      mean length(mm)\t118.336
# 2             span(mm)\t26.3569
# 3                 curl\t4.48975
# 4           elongation\t7.18531
# ...                         ...
# 19303             iso\t0.386038
# 19304             rdi\t0.254014
# 19305         nrdi02L\t0.326803
# 19306         nrdi04L\t0.128849
# 19307        nrdi06L\t0.0202953
#
#                                                   label            Codigo
# 0        sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt\t0  number of tracts  \
# 1        sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt\t1   mean length(mm)
# 2        sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt\t2          span(mm)
# 3        sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt\t3              curl
# 4        sub-10171_dwi.Arcuate_Fasciculus_L.stat.txt\t4        elongation
# ...                                                 ...               ...
# ...

# %%
import os
import csv

# Obtener la ruta de la carpeta principal 
folder_path = 'ruta_de_la_carpeta_principal'

# Crear un archivo csv
with open('datos.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Archivo', 'Contenido'])

    # Recorrer las subcarpetas y archivos txt y unirlos en un archivo csv
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.endswith('.txt'):
                filename = os.path.join(root, file)

                # Leer el archivo txt
                with open(filename, 'r') as txt_file:
                    content = txt_file.read()

                # Escribir el contenido en el archivo csv
                writer.writerow([filename, content])

print('¡Listo! Los datos se han guardado en datos.csv')
